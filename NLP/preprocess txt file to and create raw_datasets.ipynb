# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
txt_file = "/content/drive/MyDrive/HISTORIA/Datasets/_metinler_txt/cleaned_texts/hazir_metinler/rasid_tarihi/1723_tarihi_rasid.txt"

# %%
with open(txt_file, "r") as fp:
    lines = fp.readlines()

# %%
len(lines)
# Out:
# 41073

# %%
lines[0:3]
# Out:
# ['\n', '\n', '\n']

# %%
type(lines)
# Out:
# list

# %%
x = ["\n", "sasdas", "\n", "sasda", "dsfdsgdsfg"]
enumerate(x)

# %%
for i, string in enumerate(x):
    print(i, string)
# Out:
# 0
#
# 1 sasdas
# 2
#
# 3 sasda
# 4 dsfdsgdsfg

# %%
for i, string in enumerate(x):
    if string == "\n":
        del x[i]
x
# Out:
# ['sasdas', 'sasda', 'dsfdsgdsfg']

# %%
for i, line in enumerate(lines):
    if line == "\n":
        del lines[i]
len(lines)
# Out:
# 22335

# %%
lines[0:3]
# Out:
# ['\n', '\n', 'unvânü’d-dîbâce\n']

# %%
lines[0]
# Out:
# '\n'

# %%
for i, line in enumerate(lines):
    if line == "\n":
        del lines[i]
len(lines)
# Out:
# 16964

# %%
lines[0]
# Out:
# '\n'

# %%
for i, line in enumerate(lines):
    if line == "\n":
        del lines[i]
len(lines)
# Out:
# 13148

# %%
lines[0]
# Out:
# 'unvânü’d-dîbâce\n'

# %%
for i, line in enumerate(lines):
    if line == "\n":
        del lines[i]
len(lines)
# Out:
# 12770

# %%
for i, line in enumerate(lines):
    if line == "\n":
        del lines[i]
len(lines)
# Out:
# 12712

# %%
for i, line in enumerate(lines):
    if line == "\n":
        del lines[i]
len(lines)
# Out:
# 12685

# %%
for i, line in enumerate(lines):
    if line == "\n":
        del lines[i]
len(lines)
# Out:
# 12685

# %%
for i, line in enumerate(lines):
    if line == "\n":
        del lines[i]
len(lines)
# Out:
# 12685

# %%
lines[0:3]
# Out:
# ['unvânü’d-dîbâce\n',
# ...

# %%
new_txt_file = "/content/cleaned_1723_tarihi_rasid.txt"
with open(new_txt_file, "a+") as fp: 
    for line in lines:
        fp.write(line)

# %%
with open(new_txt_file, "r") as fp: 
    lines = fp.readlines()
len(lines)
# Out:
# 12685

# %%
line_lengths = []
for i, line in enumerate(lines):
    length = len(line)
    line_lengths.append(length)

# %%
len(line_lengths)
# Out:
# 12685

# %%
max(line_lengths)
# Out:
# 4199

# %%
import numpy as np
lines = np.array(lines)

# %%
top_5_idx = np.argsort(line_lengths)[-5:]
top_5_values = [line_lengths[i] for i in top_5_idx]

# %%
top_5_idx
# Out:
# array([9252, 9495, 9811, 9257, 9529])

# %%
top_5_values
# Out:
# [4096, 4135, 4164, 4165, 4199]

# %%
lines[9252]
# Out:
# 'halel verecek hâlet ihdâs etmek fikrine düşdüğünden nâşî ordu-yı hümâyûnun akd-i sulhden sonra avdet birle sofya’ya nüzûlü vaktinde vakt-i mu‘tâd-ı ulûfeden dört-beş ay mukaddem bi’l-cümle mevâcib-i kılâ‘ vü serhaddi tertîb etdirmiş iken cümleden ehemm ü akdem olan niş ve vidin serhadlerinin mevâcibi mutlak zağarcıbaşının kisb-i şöhret-kâmı içün yoklama fikriyle te’hîr ve ocak âdeti üzre ağa-yı merkūmun intifâ‘ edeceği mertebe mahlûlât getürdüp bu tarîkla ağa-yı mûmâ-ileyhi tekdîr eyledi. merkūm zağarcıbaşı dahi yeniçeri ağasından bu rütbe hilâf-gîrlik mahsûs ve menâfi‘-i melhûzadan me’yûs olmak sebebiyle mukabele kaydına düşüp mevâcibden ye’s verecek kelimât ile neferâtın gayz u kînlerin nihânîce tahrîk ve gûş-ı tuğyân u bagylerin tahrîk etdiğinden mâ‘adâ zâhirde dahi fitne vü fesâda müeddî olacak harekât ü etvârlarına ta‘arruzdan i‘râz ve niş muhâfızı vezîria‘zam-ı sâbık mehmed paşanın zabt u rabt-ı eşkıyâ husūsunda tenbîhâtını icrâdan iğmâz eyledi. askerî tâifesi bir kerre ulûfel
# ...

# %%
len(lines[9252])
# Out:
# 4096

# %%
new_txt_file = "/content/cleaned_from_empty_lines_1723_tarihi_rasid.txt"
with open(new_txt_file, "a+") as fp: 
    for line in lines:
        fp.write(line)

# %%
lines[9252][1]
# Out:
# 'a'

# %%
# !pip install datasets evaluate transformers[sentencepiece]

# %%
from datasets import load_dataset

# %%
raw_datasets = load_dataset("text", data_files="/content/cleaned_1723_tarihi_rasid.txt")
# Out:
# WARNING:datasets.builder:Using custom data configuration default-cb0e829c81656462
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-cb0e829c81656462/0.0.0/99cc88223027054f94ce0c7fd69d10eb172910fa0615671283a3c8e5e7af2f9c. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 12685
#     })
# })

# %%
raw_datasets["train"]
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 12685
# })

# %%
len(raw_datasets["train"][9252]["text"])
# Out:
# 4095

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
tokenizer = T5Tokenizer.from_pretrained("t5-base")
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:174: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"])

# %%
tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/13 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1869 > 512). Running this sequence through the model will result in indexing errors

# %%
model = T5ForConditionalGeneration.from_pretrained("t5-base")
# Out:
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]
