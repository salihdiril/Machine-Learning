# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import cv2
import os 
import numpy as np
import matplotlib.pyplot as plt
import math
from PIL import Image
import random
import matplotlib.image as mpimg
from imutils import paths
import sys
import operator

# %%
def get_paths_of_lines_and_pages(book_path):
  book = os.listdir(book_path)
  sheet_paths = []
  subpages = []
  lines = []
  for page in book:
    sheet_paths.append(book_path+"/"+page)

  for path in sheet_paths:
    page_parts = os.listdir(path)
    page_parts_paths = []
    for part in page_parts:
      page_parts_paths.append(path+"/"+part)
    subpages.append(page_parts_paths)

  for page in subpages:
    sheet = []
    for part in page:
      page_lines = os.listdir(part)
      lines_path = []
      for line in page_lines:
        lines_path.append(part+"/"+line)
      sheet.append(lines_path)
    lines.append(sheet)

  return {
      "sheet_paths": sheet_paths,
      "subpage_paths": subpages,
      "line_paths": lines
  }

# %%
pages_path = "/content/drive/MyDrive/Images/Image Lines/ESADEFENDI"
book_paths = get_paths_of_lines_and_pages(pages_path)

# %%
left_page1 = book_paths["line_paths"][0][0]
left_page1
# Out:
# ['/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_19.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_21.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_18.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_26.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_22.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_2.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_14.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_25.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_17.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_23.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_5.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_9.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_24.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_16.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_20.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_7.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_15.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_11.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_13.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_12.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_4.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_10.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_3.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_8.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_1.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_6.png']

# %%
sorted_left_page1 = sorted(left_page1, key = lambda x: int(x.split("/")[-1].split("_")[-1].split(".")[0]))
sorted_left_page1
# Out:
# ['/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_1.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_2.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_3.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_4.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_5.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_6.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_7.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_8.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_9.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_10.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_11.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_12.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_13.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_14.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_15.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_16.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_17.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_18.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_19.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_20.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_21.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_22.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_23.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_24.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_25.png',
#  '/content/drive/MyDrive/Images/Image Lines/ESADEFENDI/2 Lines/page_left/2_line_26.png']
