# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import cv2
import os 
import numpy as np
import matplotlib.pyplot as plt
import math
from PIL import Image
import random
import matplotlib.image as mpimg
from imutils import paths
import sys
import operator

# %%
x = "image133-0 Lines"
int(x.split(" ")[0].split("-")[0][5:])
# Out:
# 133

# %%
pages_path = "/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2"
book = sorted(os.listdir(pages_path), key = lambda x: int(x.split(" ")[0].split("-")[1]))
book
# Out:
# ['image1-0 Lines',
#  'image2-0 Lines',
#  'image3-0 Lines',
#  'image4-0 Lines',
#  'image5-0 Lines',
#  'image6-0 Lines',
#  'image7-0 Lines',
#  'image8-0 Lines',
#  'image9-0 Lines',
#  'image10-0 Lines',
#  'image11-0 Lines',
#  'image12-0 Lines',
#  'image13-0 Lines',
#  'image14-0 Lines',
#  'image15-0 Lines',
#  'image16-0 Lines',
#  'image17-0 Lines',
#  'image18-0 Lines',
#  'image19-0 Lines',
#  'image20-0 Lines',
#  'image21-0 Lines',
#  'image22-0 Lines',
#  'image23-0 Lines',
#  'image24-0 Lines',
#  'image25-0 Lines',
#  'image26-0 Lines',
#  'image27-0 Lines',
#  'image28-0 Lines',
#  'image29-0 Lines',
#  'image30-0 Lines',
#  'image31-0 Lines',
#  'image32-0 Lines',
#  'image33-0 Lines',
#  'image34-0 Lines',
#  'image35-0 Lines',
#  'image36-0 Lines',
#  'image37-0 Lines',
#  'image38-0 Lines',
#  'image39-0 Lines',
#  'image40-0 Lines',
#  'image41-0 Lines',
#  'image42-0 Lines',
#  'image43-0 Lines',
#  'image44-0 Lines',
#  'image45-0 Lines',
# ...

# %%
len(book)
# Out:
# 223

# %%
def get_paths_of_lines_and_pages(book_path):
  book = sorted(os.listdir(book_path), key = lambda x: int(x.split(" ")[0].split("-")[1]))
  sheet_paths = []
  for page in book:
    sheet_paths.append(book_path+"/"+page)

  line_paths = []
  for page in sheet_paths:
    page_lines = sorted(os.listdir(page), key = lambda x: int(x.split("/")[-1].split(" ")[0].split("-")[0][5:]))
    line_path = []
    for line in page_lines:
      line_path.append(page+"/"+line)
    line_paths.append(line_path)

  return {
      "sheet_paths": sheet_paths,
      "line_paths": line_paths
  }

# %%
pages_path = "/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2"
book_paths = get_paths_of_lines_and_pages(pages_path)

# %%
book_paths["sheet_paths"]
# Out:
# ['/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image2-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image3-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image4-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image5-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image6-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image7-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image8-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image9-0 Lines',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image10-0 Lines',
# ...

# %%
book_paths["line_paths"][192]
# Out:
# ['/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image193-0 Lines/image193-0_line_14.png',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image193-0 Lines/image193-0_line_3.png',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image193-0 Lines/image193-0_line_27.png',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image193-0 Lines/image193-0_line_6.png',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image193-0 Lines/image193-0_line_5.png',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image193-0 Lines/image193-0_line_17.png',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image193-0 Lines/image193-0_line_16.png',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image193-0 Lines/image193-0_line_2.png',
# ...

# %%
page1 = book_paths["sheet_paths"][0]
page1
# Out:
# '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines'

# %%
page1.split("/")[-1]
# Out:
# 'image1-0 Lines'

# %%
for page in book_paths["line_paths"][:2]:
  i = int(page[0].split("/")[-1].split(" ")[0].split("-")[0][5:])*1000
  for line in page:
    i += 1
    print(i)
# Out:
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036

# %%
for page in book_paths["line_paths"][:2]:
  for line in page:
    print(line)
# Out:
# /content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines/image1-0_line_5.png
# /content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines/image1-0_line_4.png
# /content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines/image1-0_line_6.png
# /content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines/image1-0_line_2.png
# /content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines/image1-0_line_3.png
# /content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines/image1-0_line_1.png
# /content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines/image1-0_line_7.png
# /content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/image1-0 Lines/image1-0_line_27.png
# ...

# %%
def rename_paths(book_path, parent_folder, path_dict, starting_page):
  if len(parent_folder.split("/")) - len(book_path.split("/")) == 0:
    i = starting_page
    for page in path_dict["sheet_paths"]:
      new_filename = book_path + "/" + str(i)
      os.rename(page, new_filename)
      i += 1

  elif len(parent_folder.split("/")) - len(book_path.split("/")) == 1:
    for page in path_dict["line_paths"]:
      #i = int(page[0].split("/")[-2].split(" ")[0].split("-")[0][5:])*1000
      i = int(page[0].split("/")[-2])*1000
      for line in page:
        i += 1
        new_filename = book_path + "/" + line.split("/")[-2] + "/" + str(i)
        os.rename(line, new_filename)

  else:
    print("Parent folder isn't a page, subpage or line folder!!!")

# %%
book_path = "/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2"

# %%
parent_page_path = book_path
rename_paths(book_path=book_path, parent_folder=parent_page_path, path_dict=book_paths, starting_page=1)

# %%
def get_paths_of_lines_and_pages_v2(book_path):
  book = sorted(os.listdir(book_path), key = lambda x: int(x))
  sheet_paths = []
  for page in book:
    sheet_paths.append(book_path+"/"+page)

  line_paths = []
  for page in sheet_paths:
    page_lines = sorted(os.listdir(page), key = lambda x: int(x.split("/")[-1].split(" ")[0].split("-")[0][5:]))
    line_path = []
    for line in page_lines:
      line_path.append(page+"/"+line)
    line_paths.append(line_path)

  return {
      "sheet_paths": sheet_paths,
      "line_paths": line_paths
  }

# %%
book_paths = get_paths_of_lines_and_pages_v2(pages_path)

# %%
book_paths["sheet_paths"][:10]
# Out:
# ['/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/2',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/3',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/4',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/5',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/6',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/7',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/8',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/9',
#  '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/10']

# %%
parent_line_path = book_paths["sheet_paths"][0]
parent_line_path
# Out:
# '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1'

# %%
rename_paths(book_path=book_path, parent_folder=parent_line_path, path_dict=book_paths, starting_page=1)

# %%
def get_paths_of_lines_and_pages_v3(book_path):
  book = sorted(os.listdir(book_path), key = lambda x: int(x))
  sheet_paths = []
  for page in book:
    sheet_paths.append(book_path+"/"+page)

  line_paths = []
  for page in sheet_paths:
    page_lines = sorted(os.listdir(page), key = lambda x: int(x))
    line_path = []
    for line in page_lines:
      line_path.append(page+"/"+line)
    line_paths.append(line_path)

  return {
      "sheet_paths": sheet_paths,
      "line_paths": line_paths
  }

# %%
book_paths = get_paths_of_lines_and_pages_v3(pages_path)

# %%
book_paths["line_paths"][:2]
# Out:
# [['/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1001',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1002',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1003',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1004',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1005',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1006',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1007',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1008',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1009',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1010',
#   '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1/1011',
# ...

# %%
parent_line_path = book_paths["sheet_paths"][0]
parent_line_path
# Out:
# '/content/drive/MyDrive/Line Extraction/Images/Image Lines/evliya_celebi_2v2/1'

# %%
"""def rename_paths_v2(book_path, parent_folder, path_dict, starting_page):
  if len(parent_folder.split("/")) - len(book_path.split("/")) == 0:
    i = starting_page
    for page in path_dict["sheet_paths"]:
      new_filename = book_path + "/" + str(i)
      os.rename(page, new_filename)
      i += 1

  elif len(parent_folder.split("/")) - len(book_path.split("/")) == 1:
    for page in path_dict["line_paths"]:
      i = int(page[0].split("/")[-2])*1000
      for line in page:
        i += 1
        new_filename = book_path + "/" + line.split("/")[-2] + "/" + str(i)
        os.rename(line, new_filename)

  else:
    print("Parent folder isn't a page, subpage or line folder!!!")"""

# %%
#rename_paths_v2(book_path=book_path, parent_folder=parent_line_path, path_dict=book_paths, starting_page=5)

# %%
"""for page in book_paths["line_paths"][:3]:
  print(int(page[0].split("/")[-2])*1000)
  for line in page:
    print(line.split("/")[-2])"""

# %%
book_paths = get_paths_of_lines_and_pages_v3(pages_path)

# %%
for page in book_paths["line_paths"]:
  for line in page:
    new_line = line + ".png"
    os.rename(line, new_line)
    #print(new_line)
