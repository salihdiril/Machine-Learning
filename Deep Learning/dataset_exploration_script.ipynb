# %% [markdown]
# ## Dataset building

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0, "/content/drive/MyDrive/PyTorch-Object-Detection-Faster-RCNN-Tutorial/pytorch_faster_rcnn_tutorial")
sys.path.insert(1, "/content/drive/MyDrive/PyTorch-Object-Detection-Faster-RCNN-Tutorial/pytorch_faster_rcnn_tutorial/metrics")
sys.path.insert(2, "/content/drive/MyDrive/PyTorch-Object-Detection-Faster-RCNN-Tutorial")

# %%
# imports
import pathlib

import numpy as np
from torchvision.models.detection.transform import GeneralizedRCNNTransform

from pytorch_faster_rcnn_tutorial.datasets import ObjectDetectionDataSet
from pytorch_faster_rcnn_tutorial.transformations import Clip, ComposeDouble
from pytorch_faster_rcnn_tutorial.transformations import FunctionWrapperDouble
from pytorch_faster_rcnn_tutorial.transformations import normalize_01
from pytorch_faster_rcnn_tutorial.utils import get_filenames_of_path
from pytorch_faster_rcnn_tutorial.utils import stats_dataset
from pytorch_faster_rcnn_tutorial.visual import DatasetViewer

# %%
# root directory
root = pathlib.Path('/content/drive/MyDrive/PyTorch-Object-Detection-Faster-RCNN-Tutorial/pytorch_faster_rcnn_tutorial/data/heads')

# %%
# input and target files
inputs = get_filenames_of_path(root / 'input')
targets = get_filenames_of_path(root / 'target')

inputs.sort()
targets.sort()

# %%
# mapping
mapping = {
    'head': 1,
}

# %%
# transforms
transforms = ComposeDouble([
    Clip(),
    # AlbumentationWrapper(albumentation=A.HorizontalFlip(p=0.5)),
    # AlbumentationWrapper(albumentation=A.RandomScale(p=0.5, scale_limit=0.5)),
    # AlbumentationWrapper(albumentation=A.VerticalFlip(p=0.5)),
    FunctionWrapperDouble(np.moveaxis, source=-1, destination=0),
    FunctionWrapperDouble(normalize_01)
])

# %%
# dataset building
dataset = ObjectDetectionDataSet(inputs=inputs,
                                 targets=targets,
                                 transform=transforms,
                                 use_cache=False,
                                 convert_to_format=None,
                                 mapping=mapping)

# %%
# visualize dataset
color_mapping = {
    1: 'red',
}

datasetviewer = DatasetViewer(dataset, color_mapping)
datasetviewer.napari()
datasetviewer.gui_text_properties(datasetviewer.shape_layer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_541/2744121285.py in <module>
#       5
#       6 datasetviewer = DatasetViewer(dataset, color_mapping)
# ----> 7 datasetviewer.napari()
#       8 datasetviewer.gui_text_properties(datasetviewer.shape_layer)
#
# /content/drive/MyDrive/PyTorch-Object-Detection-Faster-RCNN-Tutorial/pytorch_faster_rcnn_tutorial/visual.py in napari(self)
#      76
#      77         # Init napari instance
# ---> 78         self.viewer = napari.Viewer()
#      79
#      80         # Show current sample
#
# /usr/local/lib/python3.7/dist-packages/napari/viewer.py in __init__(self, title, ndisplay, order, axis_labels, show)
#      53         # having this import here makes all of Qt imported lazily, upon
#      54         # instantiating the first Viewer.
# ---> 55         from .window import Window
#      56
#      57         self._window = Window(self, show=show)
#
# /usr/local/lib/python3.7/dist-packages/napari/window.py in <module>
#      12
#      13 try:
# ---> 14     from ._qt import Window
#      15
#      16 except ImportError as e:
#
# /usr/local/lib/python3.7/dist-packages/napari/_qt/__init__.py in <module>
#      55
#      56 from .qt_event_loop import get_app, gui_qt, quit_app, run
# ---> 57 from .qt_main_window import Window
#
# /usr/local/lib/python3.7/dist-packages/napari/_qt/qt_main_window.py in <module>
#      33 )
#      34
# ---> 35 from ..plugins import menu_item_template as plugin_menu_item_template
#      36 from ..plugins import plugin_manager
#      37 from ..settings import get_settings
#
# /usr/local/lib/python3.7/dist-packages/napari/plugins/__init__.py in <module>
#      23
#      24 # the main plugin manager instance for the `napari` plugin namespace.
# ---> 25 plugin_manager = NapariPluginManager()
#      26 plugin_manager._initialize()
#      27
#
# /usr/local/lib/python3.7/dist-packages/napari/plugins/_plugin_manager.py in __init__(self)
#      91         self._theme_data: Dict[str, Dict[str, Theme]] = dict()
#      92
# ---> 93         if sys.platform.startswith('linux') and running_as_bundled_app():
#      94             sys.path.append(user_site_packages())
#      95
#
# /usr/local/lib/python3.7/dist-packages/napari/utils/misc.py in running_as_bundled_app()
#      63         return False
#      64     try:
# ---> 65         metadata = importlib_metadata.metadata(app_module)
#      66     except importlib_metadata.PackageNotFoundError:
#      67         return False
#
# /usr/local/lib/python3.7/dist-packages/importlib_metadata/__init__.py in metadata(distribution_name)
#    1003     :return: A PackageMetadata containing the parsed metadata.
#    1004     """
# -> 1005     return Distribution.from_name(distribution_name).metadata
#    1006
#    1007
#
# /usr/local/lib/python3.7/dist-packages/importlib_metadata/__init__.py in from_name(cls, name)
#     560         """
#     561         if not name:
# --> 562             raise ValueError("A distribution name is required.")
#     563         try:
#     564             return next(cls.discover(name=name))
#
# ValueError: A distribution name is required.

# %%
# visualize dataset with Faster-RCNN transformer
color_mapping = {
    1: 'red',
}

transform = GeneralizedRCNNTransform(min_size=1024,
                                     max_size=1024,
                                     image_mean=[0.485, 0.456, 0.406],
                                     image_std=[0.229, 0.224, 0.225])

datasetviewer = DatasetViewer(dataset, color_mapping, rccn_transform=transform)
datasetviewer.napari()

# %% [markdown]
# ## Dataset statistics

# %%
stats = stats_dataset(dataset)
stats

# %%
transform = GeneralizedRCNNTransform(min_size=1024,
                                     max_size=1024,
                                     image_mean=[0.485, 0.456, 0.406],
                                     image_std=[0.229, 0.224, 0.225])

stats_transform = stats_dataset(dataset, transform)
stats_transform
